# %%
import numpy as np
import pandas as pd

# %%
# Case study on google playstore data
df=pd.read_csv("C:\\Users\\admin\\Documents\\csv files\\PANDAS CSV\\googleplaystore.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# 1. Display Top 5 Rows of The Dataset
print('First 5 DataSets::')
df.head()
# Out:
# First 5 DataSets::
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# 1. Display Top 3 Rows of The Dataset
print('First 3 DataSets::')
df.head(3)
# Out:
# First 3 DataSets::
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
# 2. Check the Last 3 Rows of The Dataset
print('Last 3 DataSets::')
df.tail(3)
# Out:
# Last 3 DataSets::
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# ...

# %%
# 2. Check the Last 7 Rows of The Dataset
print('Last 7 DataSets::')
df.tail(7)
# Out:
# Last 7 DataSets::
#                                                  App             Category  \
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# ...

# %%
# 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)
print("Shape of Data set::",df.shape)
print('Row in dataset::',df.shape[0])
print('Columns in dataset::',df.shape[1])
# Out:
# Shape of Data set:: (10841, 13)
# Row in dataset:: 10841
# Columns in dataset:: 13

# %%
# 4. Get Information About Our Dataset Like Total Number Rows, 
#Total Number of Columns, Datatypes of Each Column And Memory Requirement
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# 5. Get Overall Statistics About The Dataframe
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include=('all'))
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
# 6. Total Number of App Titles Contain Astrology
df[df['App'].str.contains('Astrology')]
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#       Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570   161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592     2225  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840  398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#         Last Updated         Current Ver         Android Ver
# 1570   June 25, 2018          5.2.4(881)        4.0.3 and up
# 1592   July 26, 2018               4.2.1        4.0.3 and up
# 10840  July 25, 2018  Varies with device  Varies with device

# %%
# 6. Total Number of App Titles Contain Astrology
df[df['App'].str.contains('Astrology',case=False)]
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#       Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570   161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592     2225  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840  398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#         Last Updated         Current Ver         Android Ver
# 1570   June 25, 2018          5.2.4(881)        4.0.3 and up
# 1592   July 26, 2018               4.2.1        4.0.3 and up
# 10840  July 25, 2018  Varies with device  Varies with device

# %%
# 6. Total Number of App Titles Contain Astrology
nv=df[df['App'].str.contains('Astrology',case=False)]
print("Number of app title contains Astrology:::",len(nv))
# Out:
# Number of app title contains Astrology::: 3

# %%
# 7. Find Average App Rating
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
# 7. Find Average App Rating
print('Average of App Rating::',df['Rating'].mean())
# Out:
# Average of App Rating:: 4.193338315362443

# %%
# 8.  Find Total Number of Unique Category
df['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
print('Total numbers of Unique Category::',df['Category'].nunique())
# Out:
# Total numbers of Unique Category:: 34

# %%
# 9. Which Category Getting The Highest Average Rating?
df.groupby(['Category'])['Rating']

# %%
for i in df.groupby(['Category'])['Rating']:
    print(i)
# Out:
# ('1.9', 10472    19.0
# Name: Rating, dtype: float64)
# ('ART_AND_DESIGN', 0       4.1
# 1       3.9
# 2       4.7
# 3       4.5
# 4       4.3
#        ...
# 7174    NaN
# 8679    4.2
# 8712    4.3
# 8871    NaN
# 8888    5.0
# Name: Rating, Length: 65, dtype: float64)
# ('AUTO_AND_VEHICLES', 49       4.2
# 50       4.0
# 51       3.8
# 52       4.6
# 53       3.9
#         ...
# 10137    2.1
# 10345    3.9
# 10486    4.6
# 10764    NaN
# 10811    NaN
# Name: Rating, Length: 85, dtype: float64)
# ('BEAUTY', 98       4.7
# 99       4.9
# 100      4.7
# 101      3.9
# 102      3.9
# 103      4.2
# 104      4.6
# 105      4.3
# 106      4.7
# 107      4.7
# 108      4.8
# 109      4.2
# 110      4.3
# 111      4.5
# 112      4.1
# 113      NaN
# 114      4.2
# 115      4.5
# 116      4.4
# 117      4.0
# 118      4.1
# 119      4.1
# 120      4.4
# 121      4.6
# 122      4.5
# 123      NaN
# 124      3.9
# 125      4.4
# 126      NaN
# 127      4.6
# 128      3.8
# 129      NaN
# ...

# %%
df.groupby(['Category'])['Rating'].mean()
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %%
df.groupby(df['Category'])['Rating'].mean().sort_values(ascending=False).head(1)
# Out:
# Category
# 1.9    19.0
# Name: Rating, dtype: float64

# %%
# 10. Find Total Number of App having 5 Star Rating
df[df['Rating']==5]
# Out:
#                                               App   Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15
# 612                 American Girls Mobile Numbers     DATING     5.0       5
# 615                                  Awake Dating     DATING     5.0       2
# 633                         Spine- The dating app     DATING     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0       6
# ...                                           ...        ...     ...     ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0      14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0      32
# 10776                            Monster Ride Pro       GAME     5.0       1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0       4
#
# ...

# %%
# 10. Find Total Number of App having 5 Star Rating
x=df[df['Rating']==5]
print('Total Number of apps having 5 star rating::',len(x))
# Out:
# Total Number of apps having 5 star rating:: 274

# %%
# 11. Find Average Value of Reviews
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
# convert object type to float type
# df['Reviews'].astype('float')
df['Reviews']=df['Reviews'].replace('3.0M',3)

# %%
df['Reviews']=df['Reviews'].astype('float')

# %%
print('Average Value of Review::',df['Reviews'].mean())
# Out:
# Average Value of Review:: 444111.9265750392

# %%
# 12. Find Total Number of Free and Paid Apps
df['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
# 13.  Which App Has Maximum Reviews?
df['Reviews'].max()
# Out:
# 78158306.0

# %%
# 13.  Which App Has Maximum Reviews?
df[df['Reviews'].max()==df['Reviews']]
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres    Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social  August 3, 2018
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device

# %%
# 13.  Which App Has Maximum Reviews?
df[df['Reviews'].max()==df['Reviews']]['App']
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %%
# 14. Display Top 5 Apps Having Highest Reviews
ind=df['Reviews'].sort_values(ascending=False).head().index
df.iloc[ind]['App']
# Out:
# 2544              Facebook
# 3943              Facebook
# 381     WhatsApp Messenger
# 336     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: object

# %%
# 15. Find Average Rating of Free and Paid Apps
df.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
# 16. Display Top  5 Apps Having Maximum Installs
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
df['Installs'].sort_values(ascending=False).head()
# Out:
# 10472            Free
# 420      500,000,000+
# 474      500,000,000+
# 3767     500,000,000+
# 3574     500,000,000+
# Name: Installs, dtype: object

# %%
ind=df['Installs'].sort_values(ascending=False).head().index
df.loc[ind]['App']
# Out:
# 10472        Life Made WI-Fi Touchscreen Photo Frame
# 420      UC Browser - Fast Download Private & Secure
# 474                      LINE: Free Calls & Messages
# 3767                    Flipboard: News For Our Time
# 3574                                     Cloud Print
# Name: App, dtype: object

# %%
df['Installs'].dtype
# Out:
# dtype('O')

# %%
# df['Installs'].astype('float')
df['Installs']=df['Installs'].apply(lambda x:x.strip('+'))  # removing + symbol
df['Installs']=df['Installs'].apply(lambda x:x.replace(",",''))   # Removing ,
ind=df['Installs'].sort_values(ascending=False).head().index
df.loc[ind]['App']
# Out:
# 10472    Life Made WI-Fi Touchscreen Photo Frame
# 1655                            Candy Crush Saga
# 3870                                    Snapchat
# 1759                                Temple Run 2
# 3879                                         Pou
# Name: App, dtype: object
